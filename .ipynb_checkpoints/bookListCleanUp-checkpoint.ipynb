# %%
#import dependencies/libraries
import pandas as pd
import csv

# %%
#declare file
file = "Resources/books.csv"
#read into data frame
# this line gives parse error due to varying row lengths booksDF = pd.read_csv(file)

#work around by putting into list then reread to data frame
#open file, do not forget encoding!
f_work = open(file, 'rt', encoding = 'utf-8')
#read it in
reader = csv.reader(f_work)
#put into a list
csv_list = []
for item in reader:
    csv_list.append(item)
#close file
f_work.close()
#read into data frame
booksDF = pd.DataFrame(csv_list)
booksDF.head()
# Out:
#         0                                                  1  \
# 0  bookID                                              title
# 1       1  Harry Potter and the Half-Blood Prince (Harry ...
# 2       2  Harry Potter and the Order of the Phoenix (Har...
# 3       4  Harry Potter and the Chamber of Secrets (Harry...
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                             2               3           4              5  \
# 0                     authors  average_rating        isbn         isbn13
# 1  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 2  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 3                J.K. Rowling            4.42  0439554896  9780439554893
# 4  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
#
#                6            7              8                   9  \
# 0  language_code    num_pages  ratings_count  text_reviews_count
# ...
